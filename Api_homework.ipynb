# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /anaconda3/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /anaconda3/lib/python3.7/site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | batticaloa
# Processing Record 4 of Set 1 | lorengau
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | locri
# Processing Record 7 of Set 1 | deputatskiy
# Processing Record 8 of Set 1 | klaksvik
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | barahona
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | ancud
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | san andres
# Processing Record 18 of Set 1 | casper
# Processing Record 19 of Set 1 | bilma
# Processing Record 20 of Set 1 | george town
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 1 | hasaki
# Processing Record 24 of Set 1 | laela
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | nelson bay
# Processing Record 27 of Set 1 | dingle
# Processing Record 28 of Set 1 | kavaratti
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | abilene
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | yamandu
# Processing Record 33 of Set 1 | lebanon
# Processing Record 34 of Set 1 | chernyy yar
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | camana
# City not found. Skipping...
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | vila velha
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | clyde river
# Processing Record 41 of Set 1 | safety harbor
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | tabuk
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | goroka
# Processing Record 47 of Set 1 | pokosnoye
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | qandala
# Processing Record 0 of Set 2 | grand island
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 2 | chicama
# Processing Record 7 of Set 2 | kaitangata
# Processing Record 8 of Set 2 | santa maria
# Processing Record 9 of Set 2 | saint-francois
# Processing Record 10 of Set 2 | itajobi
# Processing Record 11 of Set 2 | lompoc
# Processing Record 12 of Set 2 | zhigansk
# Processing Record 13 of Set 2 | yazykovo
# Processing Record 14 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | aksu
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 18 of Set 2 | safakulevo
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | chokurdakh
# Processing Record 21 of Set 2 | mareeba
# Processing Record 22 of Set 2 | bulgan
# Processing Record 23 of Set 2 | lyngseidet
# Processing Record 24 of Set 2 | bilibino
# Processing Record 25 of Set 2 | sterlibashevo
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | finschhafen
# Processing Record 29 of Set 2 | srednekolymsk
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | pangnirtung
# Processing Record 33 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 2 | byron bay
# Processing Record 35 of Set 2 | lesosibirsk
# Processing Record 36 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 2 | kapaa
# Processing Record 38 of Set 2 | longyearbyen
# Processing Record 39 of Set 2 | samarai
# Processing Record 40 of Set 2 | hilo
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | nanortalik
# Processing Record 43 of Set 2 | norman wells
# Processing Record 44 of Set 2 | skoghall
# Processing Record 45 of Set 2 | kholm-zhirkovskiy
# Processing Record 46 of Set 2 | tilichiki
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 0 of Set 3 | ipixuna
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | saint-pierre
# Processing Record 5 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 3 | katsuura
# Processing Record 7 of Set 3 | mokhsogollokh
# Processing Record 8 of Set 3 | moose factory
# Processing Record 9 of Set 3 | coronel fabriciano
# Processing Record 10 of Set 3 | mamallapuram
# Processing Record 11 of Set 3 | yumen
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | usinsk
# Processing Record 14 of Set 3 | esperance
# Processing Record 15 of Set 3 | zasheyek
# Processing Record 16 of Set 3 | itaituba
# Processing Record 17 of Set 3 | nikolskoye
# Processing Record 18 of Set 3 | riyadh
# Processing Record 19 of Set 3 | kuryk
# Processing Record 20 of Set 3 | pisco
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 3 | najran
# Processing Record 24 of Set 3 | praia da vitoria
# Processing Record 25 of Set 3 | san patricio
# Processing Record 26 of Set 3 | beloha
# Processing Record 27 of Set 3 | alta floresta
# Processing Record 28 of Set 3 | kedougou
# Processing Record 29 of Set 3 | namatanai
# Processing Record 30 of Set 3 | sitka
# Processing Record 31 of Set 3 | constitucion
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | guymon
# Processing Record 34 of Set 3 | hirara
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | east london
# Processing Record 37 of Set 3 | guerrero negro
# Processing Record 38 of Set 3 | rundu
# Processing Record 39 of Set 3 | isangel
# Processing Record 40 of Set 3 | isiro
# Processing Record 41 of Set 3 | teguldet
# Processing Record 42 of Set 3 | chinsali
# Processing Record 43 of Set 3 | makrikapa
# City not found. Skipping...
# Processing Record 44 of Set 3 | pandan
# Processing Record 45 of Set 3 | paez
# Processing Record 46 of Set 3 | road town
# Processing Record 47 of Set 3 | aquin
# Processing Record 48 of Set 3 | roald
# Processing Record 49 of Set 3 | maragogi
# Processing Record 0 of Set 4 | the pas
# Processing Record 1 of Set 4 | ixtapa
# Processing Record 2 of Set 4 | ulladulla
# Processing Record 3 of Set 4 | maningrida
# Processing Record 4 of Set 4 | pacific grove
# Processing Record 5 of Set 4 | buriti alegre
# Processing Record 6 of Set 4 | killybegs
# Processing Record 7 of Set 4 | olafsvik
# City not found. Skipping...
# Processing Record 8 of Set 4 | awjilah
# Processing Record 9 of Set 4 | torbay
# Processing Record 10 of Set 4 | engen
# Processing Record 11 of Set 4 | husavik
# Processing Record 12 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 13 of Set 4 | thompson
# Processing Record 14 of Set 4 | mercedes
# Processing Record 15 of Set 4 | deep river
# Processing Record 16 of Set 4 | ponta do sol
# Processing Record 17 of Set 4 | meulaboh
# Processing Record 18 of Set 4 | jizan
# Processing Record 19 of Set 4 | henties bay
# Processing Record 20 of Set 4 | faanui
# Processing Record 21 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 4 | codrington
# Processing Record 23 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 4 | santa cruz de tenerife
# Processing Record 25 of Set 4 | kalmunai
# Processing Record 26 of Set 4 | marsa matruh
# Processing Record 27 of Set 4 | lagoa
# Processing Record 28 of Set 4 | el coco
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | daru
# Processing Record 31 of Set 4 | cabedelo
# Processing Record 32 of Set 4 | guayaramerin
# Processing Record 33 of Set 4 | caravelas
# Processing Record 34 of Set 4 | turukhansk
# Processing Record 35 of Set 4 | roma
# Processing Record 36 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 4 | taltal
# Processing Record 38 of Set 4 | tromso
# Processing Record 39 of Set 4 | hervey bay
# Processing Record 40 of Set 4 | mayumba
# Processing Record 41 of Set 4 | shimanovsk
# Processing Record 42 of Set 4 | kaduy
# Processing Record 43 of Set 4 | springbok
# Processing Record 44 of Set 4 | ahipara
# Processing Record 45 of Set 4 | serenje
# Processing Record 46 of Set 4 | trat
# Processing Record 47 of Set 4 | port macquarie
# Processing Record 48 of Set 4 | vadum
# Processing Record 49 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 0 of Set 5 | kyshtovka

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()

# %%
city_data_pd.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()
